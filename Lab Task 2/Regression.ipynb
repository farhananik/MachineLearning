# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Consumo_cerveja.csv')

# %%
df
# Out:
#           Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0   2015-01-01                  27.30                    23.9
# 1   2015-01-02                  27.02                    24.5
# 2   2015-01-03                  24.82                    22.4
# 3   2015-01-04                  23.98                    21.5
# 4   2015-01-05                  23.82                    21.0
# 5   2015-01-06                  23.78                    20.1
# 6   2015-01-07                  24.00                    19.5
# 7   2015-01-08                  24.90                    19.5
# 8   2015-01-09                  28.20                    21.9
# 9   2015-01-10                  26.76                    22.1
# 10  2015-01-11                  27.62                    22.2
# 11  2015-01-12                  25.96                    21.4
# 12  2015-01-13                  25.52                    21.2
# 13  2015-01-14                  25.96                    21.3
# ...

# %%
print(df.columns)
# Out:
# Index(['Data', 'Temperatura Media (C)', 'Temperatura Minima (C)',
#        'Temperatura Maxima (C)', 'Precipitacao (mm)', 'Final de Semana',
#        'Consumo de cerveja (litros)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Temperatura Media (C)  Temperatura Minima (C)  Temperatura Maxima (C)  \
# count              49.000000               49.000000               49.000000
# mean               24.488571               20.624490               30.363265
# std                 2.216371                1.776998                3.450827
# min                20.280000               17.100000               22.900000
# 25%                22.760000               19.300000               28.000000
# 50%                24.160000               20.600000               30.000000
# 75%                25.960000               22.000000               32.800000
# max                28.860000               24.500000               36.500000
#
#        Precipitacao (mm)  Final de Semana  Consumo de cerveja (litros)
# count          49.000000        49.000000                    49.000000
# mean            7.955102         0.285714                    27.450796
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Data                         49 non-null     object
#  1   Temperatura Media (C)        49 non-null     float64
#  2   Temperatura Minima (C)       49 non-null     float64
#  3   Temperatura Maxima (C)       49 non-null     float64
#  4   Precipitacao (mm)            49 non-null     float64
#  5   Final de Semana              49 non-null     int64
#  6   Consumo de cerveja (litros)  49 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.8+ KB

# %%
df.isnull().sum()
# Out:
# Data                           0
# Temperatura Media (C)          0
# Temperatura Minima (C)         0
# Temperatura Maxima (C)         0
# Precipitacao (mm)              0
# Final de Semana                0
# Consumo de cerveja (litros)    0
# dtype: int64

# %%
df['Final de Semana'].value_counts()
# Out:
# 0    35
# 1    14
# Name: Final de Semana, dtype: int64

# %%
plt.figure(figsize = (50, 10))
sns.barplot(x = 'Temperatura Media (C)', y = 'Consumo de cerveja (litros)', data = df)

plt.title("Medium Temperature vs Beer Consumption")
# Out:
# Text(0.5, 1.0, 'Medium Temperature vs Beer Consumption')

# %%
plt.figure(figsize = (50, 10))
sns.barplot(x = 'Temperatura Minima (C)', y = 'Consumo de cerveja (litros)', data = df)

plt.title("Minimum Temperature vs Beer Consumption")
# Out:
# Text(0.5, 1.0, 'Minimum Temperature vs Beer Consumption')

# %%
plt.figure(figsize = (50, 10))
sns.barplot(x = 'Temperatura Maxima (C)', y = 'Consumo de cerveja (litros)', data = df)

plt.title("Maximum Temperature vs Beer Consumption")
# Out:
# Text(0.5, 1.0, 'Maximum Temperature vs Beer Consumption')

# %%
df.drop(['Data', 'Precipitacao (mm)', 'Final de Semana'], axis=1, inplace=True)

# %%
f, ax = plt.subplots(figsize = (10, 10))

corr = df.corr()
sns.heatmap(corr, mask = np.zeros_like(corr, dtype = bool), 
            cmap = sns.diverging_palette(50, 10, as_cmap = True), square = True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns=['Consumo de cerveja (litros)'])
y = df['Consumo de cerveja (litros)']

# %%
print(X.shape)
X.sample(10)
# Out:
# (49, 3)
#     Temperatura Media (C)  Temperatura Minima (C)  Temperatura Maxima (C)
# 24                  24.40                    18.1                    30.0
# 21                  21.74                    19.2                    26.1
# 9                   26.76                    22.1                    34.2
# 14                  25.86                    21.5                    32.8
# 39                  24.00                    19.3                    30.7
# 41                  25.38                    19.9                    30.4
# 13                  25.96                    21.3                    34.0
# 34                  22.12                    19.9                    23.7
# 8                   28.20                    21.9                    34.0
# 3                   23.98                    21.5                    28.6

# %%
print(y.shape)
y.tail(10)
# Out:
# (49,)
# 39    24.062
# 40    21.137
# 41    26.805
# 42    26.389
# 43    24.219
# 44    30.231
# 45    24.968
# 46    25.343
# 47    17.399
# 48    21.392
# Name: Consumo de cerveja (litros), dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2 , random_state = 1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (39, 3)
# (10, 3)
# (39,)
# (10,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,accuracy_score,r2_score

from math import sqrt

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

MSE = mean_squared_error(y_test, y_pred)
print('MSE: ', MSE)

RMSE = sqrt(mean_squared_error(y_test, y_pred))       
print('RMSE: ', RMSE)

R2 = r2_score(y_test, y_pred)
print('R2 :', R2)
# Out:
# MSE:  15.474144885860847
# RMSE:  3.9337189637620082
# R2 : -0.9703484417764618

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

svr.fit(X_train, y_train)

y_pred = svr.predict(X_test)

MSE = mean_squared_error(y_test, y_pred)
print('MSE: ', MSE)

RMSE = sqrt(mean_squared_error(y_test, y_pred))       
print('RMSE: ', RMSE)

R2 = r2_score(y_test, y_pred)
print('R2 :', R2)
# Out:
# MSE:  9.985001415903241
# RMSE:  3.1599052859070382
# R2 : -0.2714067320732747

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

dtr.fit(X_train, y_train)

y_pred = dtr.predict(X_test)

MSE = mean_squared_error(y_test, y_pred)
print('MSE: ', MSE)

RMSE = sqrt(mean_squared_error(y_test, y_pred))       
print('RMSE: ', RMSE)

R2 = r2_score(y_test, y_pred)
print('R2 :', R2)
# Out:
# MSE:  17.469556599999994
# RMSE:  4.179659866544165
# R2 : -1.2244275130697022

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators = 40, max_depth = 4, n_jobs = -1)

rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)

MSE = mean_squared_error(y_test, y_pred)
print('MSE: ', MSE)

RMSE = sqrt(mean_squared_error(y_test, y_pred))       
print('RMSE: ', RMSE)

R2 = r2_score(y_test, y_pred)
print('R2 :', R2)
# Out:
# MSE:  14.258779169080668
# RMSE:  3.7760798679425025
# R2 : -0.8155939164757162
